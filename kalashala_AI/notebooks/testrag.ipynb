# %%
from rag import *

initialize_rag("data")

while True:

    question = input("Ask : ")

    if question.lower() == "exit":
        break

    print(answer_question(question))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from rag import *
# ----> 3 initialize_rag("data")
#       5 while True:
#       7     question = input("Ask : ")
#
# File ~\kalashala_AI\rag.py:315, in initialize_rag(data_path)
#     312 global index
#     313 global bm25
# --> 315 embedding_model = SentenceTransformer(
#     316     "BAAI/bge-base-en-v1.5"
#     317 )
#     319 reranker = CrossEncoder(
#     320     "cross-encoder/ms-marco-MiniLM-L-6-v2"
#     321 )
#     323 documents = load_documents(data_path)
#
# NameError: name 'SentenceTransformer' is not defined

# %%
from rag import *

docs = load_documents("data")

chunks = create_chunks(docs)

print(chunks[0])
# Out:
# Loaded 5 markdown files.
# Created 18 chunks.
# {'chunk_id': 0, 'file': 'academy.md', 'text': 'Kalashala Makeup Academy', 'header': {'header1': 'Academy Name:'}}

# %%
from rag import *

embedding_model = SentenceTransformer(
    "BAAI/bge-base-en-v1.5"
)

docs = load_documents("data")

chunks = create_chunks(docs)

embeddings = build_embeddings(chunks)

faiss_index = build_faiss_index(embeddings)

bm25_index = build_bm25_index(chunks)

print(embeddings.shape)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Loaded 5 markdown files.
# Created 18 chunks.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 11
#       7 docs = load_documents("data")
#       9 chunks = create_chunks(docs)
# ---> 11 embeddings = build_embeddings(chunks)
#      13 faiss_index = build_faiss_index(embeddings)
#      15 bm25_index = build_bm25_index(chunks)
#
# File ~\kalashala_AI\rag.py:140, in build_embeddings(chunks)
#     136 def build_embeddings(chunks):
#     138     texts = [chunk["text"] for chunk in chunks]
# --> 140     embeddings = embedding_model.encode(
#     141         texts,
#     142         normalize_embeddings=True,
#     143         show_progress_bar=True
#     144     )
#     146     return embeddings
#
# AttributeError: 'NoneType' object has no attribute 'encode'

# %%
import importlib
import rag

importlib.reload(rag)

from rag import *

# %%
print(build_embeddings)
# Out:
# <function build_embeddings at 0x00000270C6652CA0>

# %%
def initialize_rag(data_path):

    global embedding_model
    global reranker
    global all_chunks
    global index
    global bm25

    embedding_model = SentenceTransformer(
        "BAAI/bge-base-en-v1.5"
    )

    reranker = CrossEncoder(
        "cross-encoder/ms-marco-MiniLM-L-6-v2"
    )

    documents = load_documents(data_path)

    all_chunks = create_chunks(documents)

    embeddings = build_embeddings(all_chunks)

    index = build_faiss_index(embeddings)

    bm25 = build_bm25_index(all_chunks)

    print("RAG Initialized Successfully!")

# %%
from rag import *

initialize_rag("data")

print(answer_question("Where is the academy located?"))
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# Loaded 5 markdown files.
# Created 18 chunks.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 from rag import *
# ----> 3 initialize_rag("data")
#       5 print(answer_question("Where is the academy located?"))
#
# Cell In[4], line 21, in initialize_rag(data_path)
#      17 documents = load_documents(data_path)
#      19 all_chunks = create_chunks(documents)
# ---> 21 embeddings = build_embeddings(all_chunks)
#      23 index = build_faiss_index(embeddings)
#      25 bm25 = build_bm25_index(all_chunks)
#
# File ~\kalashala_AI\rag.py:140, in build_embeddings(chunks)
#     136 def build_embeddings(chunks):
#     138     texts = [chunk["text"] for chunk in chunks]
# --> 140     embeddings = embedding_model.encode(
#     141         texts,
#     142         normalize_embeddings=True,
#     143         show_progress_bar=True
#     144     )
#     146     return embeddings
#
# AttributeError: 'NoneType' object has no attribute 'encode'

# %%
import asyncio

# %%
asyncio.run(connect())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 asyncio.run(connect())
#
# NameError: name 'connect' is not defined

# %%
import ollama
import json

from fastmcp import Client

import asyncio


client = Client("mcp_server.py")

async def chat():

    async with client:

        tools = await client.list_tools()

        print(tools)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(tools)
#
# NameError: name 'tools' is not defined

# %%
pip show mcp
# Out:
# Name: mcp
# Version: 1.28.1
# Summary: Model Context Protocol SDK
# Home-page: https://modelcontextprotocol.io
# Author: Anthropic, PBC.
# Author-email:
# License: MIT
# Location: C:\Users\USER\AppData\Roaming\Python\Python313\site-packages
# Requires: anyio, httpx, httpx-sse, jsonschema, pydantic, pydantic-settings, pyjwt, python-multipart, pywin32, sse-starlette, starlette, typing-extensions, typing-inspection, uvicorn
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
